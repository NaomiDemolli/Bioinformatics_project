# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from retrieve_preprocessed_dataset import *

# %% [markdown]
# 1) retrieve_dataset.py to download epigenomic_dataset and FANTOM
#
# 2) retrieve_sequence.ipynb to download Genome sequence
#
# 3) labels_threshold.py: analysis of labels and different solutions for binarizing them
#
# 3) pre_processing.py: NaN imputation, normalization
#
# 4) correlations.py: remove features correlated with output and features related to each other
#
# 5) feature_selection: use of Boruta algorithm to determine relevant features
#
# 6) PCA

# %% [markdown]
# ### Label

# %% [markdown]
# ### Features distribution

# %%
from sklearn.metrics.pairwise import euclidean_distances

# %%
def get_top_most_different(dist, n:int):
    return np.argsort(-np.mean(dist, axis = 1).flatten())[:n]

# %%
top_number = 5

for region, x in epigenomes.items():
    dist = euclidean_distances(x.T)
    most_distance_columns_indices = get_top_most_different(dist, top_number)
    columns = x.columns[most_distance_columns_indices]
    fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(25, 5))
    print(f"Top {top_number} different features from {region}.")
    for column, axis in zip(columns, axes.flatten()):
        head, tail = x[column].quantile([0.05, 0.95]).values.ravel()
        
        mask = ((x[column] < tail) & (x[column] > head)).values
        
        cleared_x = x[column][mask]
        cleared_y = labels[region].values.ravel()[mask]
        
        cleared_x[cleared_y==0].hist(ax=axis, bins=20)
        cleared_x[cleared_y==1].hist(ax=axis, bins=20)

        axis.set_title(column, fontsize=20)
    fig.tight_layout()
    plt.savefig(f'.\\img\\features_distribution_{region}.jpg')
    plt.show()
# Out:
# Top 5 different features from promoters.
# Top 5 different features from enhancers.

# %% [markdown]
# #### Retrieve sequence

# %%
from ucsc_genomes_downloader import Genome
genome = Genome("hg38")
# Out:
# Loading chromosomes for genome hg38:   0%|                                                      | 0/25 [00:00<…

# %%
def to_bed(data:pd.DataFrame)->pd.DataFrame:
    """Return bed coordinates from given dataset."""
    return data.reset_index()[data.index.names]

# %% [markdown]
# ## MODEL

# %%
from typing import Dict, List, Tuple, Optional
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, ReLU, Concatenate, Layer
from tensorflow.keras.layers import Conv1D, MaxPool1D, GlobalAveragePooling1D, GlobalMaxPool1D, Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model, Sequential
from extra_keras_metrics import get_complete_binary_metrics
from tensorflow import keras

# %%
# def build_functional_perceptron(input_shape: int)-> Model:

#     input_epigenomic_data = Input(shape = (input_shape,), name = "epigenomic_data")
#     output = Dense(1, activation = "sigmoid")(input_epigenomic_data)

#     perceptron = Model(
#         inputs = input_epigenomic_data,
#         outputs = output,
#         name = "perc"
#     ) 

#     perceptron.compile(
#         optimizer = "nadam",
#         loss = "binary_crossentropy",
#         metrics = get_complete_binary_metrics()
#     )
    
#     return perceptron

# %%
def build_perceptron(input_shape: int)->Tuple[Model, Layer, Layer]:

    input_epigenomic_data = Input(shape=(input_shape,), name="epigenomic_data")
    output_ffnn = Dense(1, activation="sigmoid")(input_epigenomic_data)

    perceptron = Model(
        inputs=input_epigenomic_data,
        outputs=output_ffnn,
        name="perc"
    )

    perceptron.compile(
        optimizer="nadam",
        loss="binary_crossentropy",
        metrics=get_complete_binary_metrics()
    )
    return perceptron, input_epigenomic_data, output_ffnn

# %%
# # SEQUENTIAL

# def build_ffnn(input_shape:int) -> Tuple[Model, Layer, Layer]:
    
#     input_epigenomic_data = Input(shape = (input_shape,), name = "epigenomic_data")
#     output = Dense(1, activation="sigmoid")
    
#     ffnn = Sequential([
#         input_epigenomic_data,
#         Dense(16, activation = 'relu'),
#         Dense(4, activation="relu"),
#         output
#     ])
    
#     last_hidden = Dense(4, activation="relu")
#     model._name = 'FFNN'
    
#     ffnn.compile(
#         optimizer = "SGD", 
#         loss = "binary_crossentropy", 
#         metrics = get_complete_binary_metrics())
    
#     return ffnn, input_epigenomic_data, last_hidden

# %%
def build_functional_ffnn(input_shape:int) -> Tuple[Model, Layer, Layer]:
    
    input_epigenomic_data = Input(shape=(input_shape,), name="epigenomic_data")
    hidden = Dense(16, activation="relu")(input_epigenomic_data)

    for _ in range(1):
        hidden = Dense(4, activation="relu")(hidden)
        hidden = Dense(2, activation="relu")(hidden)

    last_hidden_ffnn = hidden
    output_ffnn = Dense(1, activation="sigmoid")(hidden)

    ffnn = Model(
        inputs=input_epigenomic_data,
        outputs=output_ffnn,
        name="FFNN"
    )

    ffnn.compile(
        optimizer = "nadam", 
        loss = "binary_crossentropy", 
        metrics = get_complete_binary_metrics())
    
    return ffnn, input_epigenomic_data, last_hidden_ffnn

# %%
def build_functional_cnn(window_size: int)->Tuple[Model, Layer, Layer]:

    input_sequence_data = Input(shape=(window_size, 4), name="sequence_data")
    hidden = Conv1D(64, kernel_size=6, activation="relu")(input_sequence_data)
    hidden = MaxPool1D(pool_size=2)(hidden)
    hidden = Conv1D(128, kernel_size=3, activation="relu")(hidden)
    hidden = GlobalAveragePooling1D()(hidden)
    hidden = Dropout(rate=0.5)(hidden)
    
    last_hidden_cnn =  Dense(10, activation = 'relu')(hidden)
    output_cnn = Dense(1, activation="sigmoid")(last_hidden_cnn)
    
    cnn = Model(
        inputs=input_sequence_data,
        outputs=output_cnn,
        name="CNN"
    )

    cnn.compile(
        optimizer="nadam",
        loss="binary_crossentropy",
        metrics=get_complete_binary_metrics()
    )
    return cnn, input_sequence_data, last_hidden_cnn

# %%
# def build_sequential_cnn(window_size: int):
   
#     input_sequence_data = Input(shape=(window_size,4 ), name="sequence_data")
#     output =  Dense(1, activation="sigmoid")
    
#     model = Sequential([
#         input_sequence_data,
#         Conv1D(64, kernel_size=5, activation="relu"),
#         MaxPool1D(pool_size=2),
#         Conv1D(128, kernel_size=3, activation="relu"),
#         GlobalAveragePooling1D(),
#         Dropout(rate=0.5),
#         Dense(10, activation = 'relu'),
#         Dropout(rate=0.5),
#         output
#     ])
    
#     model._name = 'CNN'


#     model.compile(
#         optimizer="nadam",
#         loss="binary_crossentropy",
#         metrics=get_complete_binary_metrics()
#     )
#     return model

# %%
def build_mmnn(
    input_shape: Optional[int] = None,
    window_size: Optional[int] = None,
    input_epigenomic_data: Optional[Layer] = None,
    input_sequence_data: Optional[Layer] = None,
    last_hidden_ffnn: Optional[Layer] = None,
    last_hidden_cnn: Optional[Layer] = None,
):

    if input_shape is None and (last_hidden_ffnn is None or input_epigenomic_data is None):
        raise ValueError(
            "Either the input shape or the features selection layer and the input epigenomic "
            "layer must be provided."
        )
    if window_size is None and (last_hidden_cnn is None or input_sequence_data is None):
        raise ValueError(
            "Either the input shape or the features selection layer and the input sequence "
            "layer must be provided."
        )
        
    if input_shape is not None:
        _, input_epigenomic_data, last_hidden_ffnn = build_functional_ffnn(input_shape)
        
    if window_size is not None:
        _, input_sequence_data, last_hidden_cnn = build_functional_cnn(window_size)
        
    concatenation_layer = Concatenate()([
        last_hidden_ffnn,
        last_hidden_cnn
    ])

    last_hidden_mmnn = Dense(64, activation="relu")(concatenation_layer)
    output_mmnn = Dense(1, activation="sigmoid")(last_hidden_mmnn)

    mmnn = Model(
        inputs=[input_epigenomic_data, input_sequence_data],
        outputs=output_mmnn,
        name="BoostedMMNN" if input_shape is None else "MMNN"
    )

    mmnn.compile(
        optimizer="nadam",
        loss="binary_crossentropy",
        metrics=get_complete_binary_metrics()
    )

    return mmnn

# %% [markdown]
# ## Training

# %% [markdown]
# #### get sequences

# %%
from keras_mixed_sequence import MixedSequence, VectorSequence
from keras_bed_sequence import BedSequence

def get_ffnn_sequence(X: np.ndarray, y: np.ndarray, batch_size: int = 1024) -> MixedSequence:

    return MixedSequence(
        
        x = {"epigenomic_data": VectorSequence(X, batch_size)},
        
        y = VectorSequence(y, batch_size)
    )

from keras_bed_sequence import BedSequence


def get_cnn_sequence(
    genome: Genome,
    bed: pd.DataFrame,
    y: np.ndarray,
    batch_size: int = 1024) -> MixedSequence:

    return MixedSequence(
        x={
            "sequence_data": BedSequence(
                genome,
                bed,
                batch_size=batch_size,
            )
        },
        y=VectorSequence(
            y,
            batch_size=batch_size
        )
    )


def get_mmnn_sequence(
    genome: Genome,
    bed: pd.DataFrame,
    X: np.ndarray,
    y: np.ndarray,
    batch_size: int = 1024) -> MixedSequence:

    return MixedSequence(
        x={
            "sequence_data": BedSequence(
                genome,
                bed,
                batch_size=batch_size,
            ),
            "epigenomic_data": VectorSequence(
                X,
                batch_size
            )
        },
        y=VectorSequence(
            y,
            batch_size=batch_size
        )
    )

# %%
from tensorflow.keras.callbacks import EarlyStopping

def train_model(
    model: Model,
    model_name: str,
    task: str,
    train_sequence,
    test_sequence,
    holdout_number: int) -> Tuple[pd.DataFrame, pd.DataFrame]:

    history = pd.DataFrame(model.fit(
        train_sequence,
        validation_data = test_sequence,
        epochs = 10,
        verbose = False,
        callbacks = [EarlyStopping("loss", min_delta = 0.001, patience = 2, mode = "min"),]).history)
    
    train_evaluation = dict(zip(model.metrics_names, model.evaluate(train_sequence, verbose = False)))
    test_evaluation = dict(zip(model.metrics_names, model.evaluate(test_sequence, verbose = False)))
    train_evaluation["run_type"] = "train"
    test_evaluation["run_type"] = "test"
    
    for evaluation in (train_evaluation, test_evaluation):
        evaluation["model_name"] = model_name
        evaluation["task"] = task
        evaluation["holdout_number"] = holdout_number
    
    evaluations = pd.DataFrame([
        train_evaluation,
        test_evaluation
    ])
    
    return history, evaluations

# %% [markdown]
# #### Holdout

# %%
from sklearn.model_selection import StratifiedShuffleSplit, ShuffleSplit

number_of_splits = 50

holdouts_generator = StratifiedShuffleSplit(
    n_splits = number_of_splits,
    test_size = 0.2
)

# %% [markdown]
# #### Training perceptron, ffnn, cnn

# %%
all_binary_classification_performance = []

training_histories = {}
window_size = 256

for region, X in epigenomes.items():

    y = labels[region]
    training_histories[region] = []

    number_of_features = X.shape[1]
    bed = to_bed(X)
    
    for holdout_index, (train_indices, test_indices) in enumerate(holdouts_generator.split(X, y)):
        
        train_bed, test_bed = bed.iloc[train_indices], bed.iloc[test_indices]
        train_X, test_X = X.iloc[train_indices].values , X.iloc[test_indices].values 
        train_y, test_y = y.iloc[train_indices], y.iloc[test_indices]
        
        train_y = train_y.values.flatten()
        test_y = test_y.values.flatten()
          
        perceptron,_ ,_ = build_perceptron(number_of_features)
        ffnn, input_epigenomic_data, last_hidden_ffnn = build_functional_ffnn(number_of_features)
        cnn, input_sequence_data, last_hidden_cnn = build_functional_cnn(window_size)
        mmnn1 = build_mmnn(number_of_features, window_size)
        
        mmnn2 = build
        _mmnn(
            input_sequence_data=input_sequence_data,
            input_epigenomic_data=input_epigenomic_data,
            last_hidden_ffnn=last_hidden_ffnn,
            last_hidden_cnn=last_hidden_cnn
        )

        train_ffnn_sequence = get_ffnn_sequence(train_X, train_y)
        test_ffnn_sequence = get_ffnn_sequence(test_X, test_y)
        train_cnn_sequence = get_cnn_sequence(genome, train_bed, train_y) 
        test_cnn_sequence = get_cnn_sequence(genome, test_bed, test_y)
        train_mmnn_sequence = get_mmnn_sequence(genome, train_bed, train_X, train_y)
        test_mmnn_sequence =  get_mmnn_sequence(genome, test_bed, test_X, test_y)
        
        for model, train_sequence, test_sequence in [
            (perceptron,  train_ffnn_sequence, test_ffnn_sequence),
            (ffnn, train_ffnn_sequence, test_ffnn_sequence),
            (cnn,  train_cnn_sequence, test_cnn_sequence),
            (mmnn1, train_mmnn_sequence, test_mmnn_sequence),
            (mmnn2, train_mmnn_sequence, test_mmnn_sequence)
        ]:
            
            print('task on ' + str(region) + " - " + str(holdout_index + 1) + " holdout - model: " + model.name)
        
            history, performance = train_model(
                    model,
                    model.name,
                    task = region,
                    train_sequence = train_sequence,
                    test_sequence = test_sequence,
                    holdout_number = holdout_index
                )

            all_binary_classification_performance.append(performance)
    print("-"*80)
        
all_binary_classification_performance = pd.concat(all_binary_classification_performance)
# Out:
# task on promoters - 1 holdout - model: perc
# task on promoters - 1 holdout - model: FFNN
# task on promoters - 1 holdout - model: CNN
# task on promoters - 1 holdout - model: MMNN
# task on promoters - 1 holdout - model: BoostedMMNN
# task on promoters - 2 holdout - model: perc
# task on promoters - 2 holdout - model: FFNN
# task on promoters - 2 holdout - model: CNN
# task on promoters - 2 holdout - model: MMNN
# task on promoters - 2 holdout - model: BoostedMMNN
# task on promoters - 3 holdout - model: perc
# task on promoters - 3 holdout - model: FFNN
# task on promoters - 3 holdout - model: CNN
# task on promoters - 3 holdout - model: MMNN
# task on promoters - 3 holdout - model: BoostedMMNN
# task on promoters - 4 holdout - model: perc
# task on promoters - 4 holdout - model: FFNN
# task on promoters - 4 holdout - model: CNN
# task on promoters - 4 holdout - model: MMNN
# task on promoters - 4 holdout - model: BoostedMMNN
# task on promoters - 5 holdout - model: perc
# task on promoters - 5 holdout - model: FFNN
# task on promoters - 5 holdout - model: CNN
# task on promoters - 5 holdout - model: MMNN
# task on promoters - 5 holdout - model: BoostedMMNN
# task on promoters - 6 holdout - model: perc
# task on promoters - 6 holdout - model: FFNN
# task on promoters - 6 holdout - model: CNN
# task on promoters - 6 holdout - model: MMNN
# task on promoters - 6 holdout - model: BoostedMMNN
# task on promoters - 7 holdout - model: perc
# task on promoters - 7 holdout - model: FFNN
# task on promoters - 7 holdout - model: CNN
# task on promoters - 7 holdout - model: MMNN
# task on promoters - 7 holdout - model: BoostedMMNN
# task on promoters - 8 holdout - model: perc
# task on promoters - 8 holdout - model: FFNN
# task on promoters - 8 holdout - model: CNN
# task on promoters - 8 holdout - model: MMNN
# task on promoters - 8 holdout - model: BoostedMMNN
# task on promoters - 9 holdout - model: perc
# task on promoters - 9 holdout - model: FFNN
# task on promoters - 9 holdout - model: CNN
# task on promoters - 9 holdout - model: MMNN
# task on promoters - 9 holdout - model: BoostedMMNN
# task on promoters - 10 holdout - model: perc
# task on promoters - 10 holdout - model: FFNN
# task on promoters - 10 holdout - model: CNN
# task on promoters - 10 holdout - model: MMNN
# task on promoters - 10 holdout - model: BoostedMMNN
# task on promoters - 11 holdout - model: perc
# task on promoters - 11 holdout - model: FFNN
# task on promoters - 11 holdout - model: CNN
# task on promoters - 11 holdout - model: MMNN
# task on promoters - 11 holdout - model: BoostedMMNN
# task on promoters - 12 holdout - model: perc
# task on promoters - 12 holdout - model: FFNN
# task on promoters - 12 holdout - model: CNN
# task on promoters - 12 holdout - model: MMNN
# task on promoters - 12 holdout - model: BoostedMMNN
# task on promoters - 13 holdout - model: perc
# task on promoters - 13 holdout - model: FFNN
# task on promoters - 13 holdout - model: CNN
# task on promoters - 13 holdout - model: MMNN
# task on promoters - 13 holdout - model: BoostedMMNN
# task on promoters - 14 holdout - model: perc
# task on promoters - 14 holdout - model: FFNN
# task on promoters - 14 holdout - model: CNN
# task on promoters - 14 holdout - model: MMNN
# task on promoters - 14 holdout - model: BoostedMMNN
# task on promoters - 15 holdout - model: perc
# task on promoters - 15 holdout - model: FFNN
# task on promoters - 15 holdout - model: CNN
# task on promoters - 15 holdout - model: MMNN
# task on promoters - 15 holdout - model: BoostedMMNN
# task on promoters - 16 holdout - model: perc
# task on promoters - 16 holdout - model: FFNN
# task on promoters - 16 holdout - model: CNN
# task on promoters - 16 holdout - model: MMNN
# task on promoters - 16 holdout - model: BoostedMMNN
# task on promoters - 17 holdout - model: perc
# task on promoters - 17 holdout - model: FFNN
# task on promoters - 17 holdout - model: CNN
# task on promoters - 17 holdout - model: MMNN
# task on promoters - 17 holdout - model: BoostedMMNN
# task on promoters - 18 holdout - model: perc
# task on promoters - 18 holdout - model: FFNN
# task on promoters - 18 holdout - model: CNN
# task on promoters - 18 holdout - model: MMNN
# task on promoters - 18 holdout - model: BoostedMMNN
# task on promoters - 19 holdout - model: perc
# task on promoters - 19 holdout - model: FFNN
# task on promoters - 19 holdout - model: CNN
# task on promoters - 19 holdout - model: MMNN
# task on promoters - 19 holdout - model: BoostedMMNN
# task on promoters - 20 holdout - model: perc
# task on promoters - 20 holdout - model: FFNN
# task on promoters - 20 holdout - model: CNN
# task on promoters - 20 holdout - model: MMNN
# task on promoters - 20 holdout - model: BoostedMMNN
# task on promoters - 21 holdout - model: perc
# task on promoters - 21 holdout - model: FFNN
# task on promoters - 21 holdout - model: CNN
# task on promoters - 21 holdout - model: MMNN
# task on promoters - 21 holdout - model: BoostedMMNN
# task on promoters - 22 holdout - model: perc
# task on promoters - 22 holdout - model: FFNN
# task on promoters - 22 holdout - model: CNN
# task on promoters - 22 holdout - model: MMNN
# task on promoters - 22 holdout - model: BoostedMMNN
# task on promoters - 23 holdout - model: perc
# task on promoters - 23 holdout - model: FFNN
# task on promoters - 23 holdout - model: CNN
# task on promoters - 23 holdout - model: MMNN
# task on promoters - 23 holdout - model: BoostedMMNN
# task on promoters - 24 holdout - model: perc
# task on promoters - 24 holdout - model: FFNN
# task on promoters - 24 holdout - model: CNN
# task on promoters - 24 holdout - model: MMNN
# task on promoters - 24 holdout - model: BoostedMMNN
# task on promoters - 25 holdout - model: perc
# task on promoters - 25 holdout - model: FFNN
# task on promoters - 25 holdout - model: CNN
# task on promoters - 25 holdout - model: MMNN
# task on promoters - 25 holdout - model: BoostedMMNN
# task on promoters - 26 holdout - model: perc
# task on promoters - 26 holdout - model: FFNN
# task on promoters - 26 holdout - model: CNN
# task on promoters - 26 holdout - model: MMNN
# task on promoters - 26 holdout - model: BoostedMMNN
# task on promoters - 27 holdout - model: perc
# task on promoters - 27 holdout - model: FFNN
# task on promoters - 27 holdout - model: CNN
# task on promoters - 27 holdout - model: MMNN
# task on promoters - 27 holdout - model: BoostedMMNN
# task on promoters - 28 holdout - model: perc
# task on promoters - 28 holdout - model: FFNN
# task on promoters - 28 holdout - model: CNN
# task on promoters - 28 holdout - model: MMNN
# task on promoters - 28 holdout - model: BoostedMMNN
# task on promoters - 29 holdout - model: perc
# task on promoters - 29 holdout - model: FFNN
# task on promoters - 29 holdout - model: CNN
# task on promoters - 29 holdout - model: MMNN
# task on promoters - 29 holdout - model: BoostedMMNN
# task on promoters - 30 holdout - model: perc
# task on promoters - 30 holdout - model: FFNN
# task on promoters - 30 holdout - model: CNN
# task on promoters - 30 holdout - model: MMNN
# task on promoters - 30 holdout - model: BoostedMMNN
# task on promoters - 31 holdout - model: perc
# task on promoters - 31 holdout - model: FFNN
# task on promoters - 31 holdout - model: CNN
# task on promoters - 31 holdout - model: MMNN
# task on promoters - 31 holdout - model: BoostedMMNN
# task on promoters - 32 holdout - model: perc
# task on promoters - 32 holdout - model: FFNN
# task on promoters - 32 holdout - model: CNN
# task on promoters - 32 holdout - model: MMNN
# task on promoters - 32 holdout - model: BoostedMMNN
# task on promoters - 33 holdout - model: perc
# task on promoters - 33 holdout - model: FFNN
# task on promoters - 33 holdout - model: CNN
# task on promoters - 33 holdout - model: MMNN
# task on promoters - 33 holdout - model: BoostedMMNN
# task on promoters - 34 holdout - model: perc
# task on promoters - 34 holdout - model: FFNN
# task on promoters - 34 holdout - model: CNN
# task on promoters - 34 holdout - model: MMNN
# task on promoters - 34 holdout - model: BoostedMMNN
# task on promoters - 35 holdout - model: perc
# task on promoters - 35 holdout - model: FFNN
# task on promoters - 35 holdout - model: CNN
# task on promoters - 35 holdout - model: MMNN
# task on promoters - 35 holdout - model: BoostedMMNN
# task on promoters - 36 holdout - model: perc
# task on promoters - 36 holdout - model: FFNN
# task on promoters - 36 holdout - model: CNN
# task on promoters - 36 holdout - model: MMNN
# task on promoters - 36 holdout - model: BoostedMMNN
# task on promoters - 37 holdout - model: perc
# task on promoters - 37 holdout - model: FFNN
# task on promoters - 37 holdout - model: CNN
# task on promoters - 37 holdout - model: MMNN
# task on promoters - 37 holdout - model: BoostedMMNN
# task on promoters - 38 holdout - model: perc
# task on promoters - 38 holdout - model: FFNN
# task on promoters - 38 holdout - model: CNN
# task on promoters - 38 holdout - model: MMNN
# task on promoters - 38 holdout - model: BoostedMMNN
# task on promoters - 39 holdout - model: perc
# task on promoters - 39 holdout - model: FFNN
# task on promoters - 39 holdout - model: CNN
# task on promoters - 39 holdout - model: MMNN
# task on promoters - 39 holdout - model: BoostedMMNN
# task on promoters - 40 holdout - model: perc
# task on promoters - 40 holdout - model: FFNN
# task on promoters - 40 holdout - model: CNN
# task on promoters - 40 holdout - model: MMNN
# task on promoters - 40 holdout - model: BoostedMMNN
# task on promoters - 41 holdout - model: perc
# task on promoters - 41 holdout - model: FFNN
# task on promoters - 41 holdout - model: CNN
# task on promoters - 41 holdout - model: MMNN
# task on promoters - 41 holdout - model: BoostedMMNN
# task on promoters - 42 holdout - model: perc
# task on promoters - 42 holdout - model: FFNN
# task on promoters - 42 holdout - model: CNN
# task on promoters - 42 holdout - model: MMNN
# task on promoters - 42 holdout - model: BoostedMMNN
# task on promoters - 43 holdout - model: perc
# task on promoters - 43 holdout - model: FFNN
# task on promoters - 43 holdout - model: CNN
# task on promoters - 43 holdout - model: MMNN
# task on promoters - 43 holdout - model: BoostedMMNN
# task on promoters - 44 holdout - model: perc
# task on promoters - 44 holdout - model: FFNN
# task on promoters - 44 holdout - model: CNN
# task on promoters - 44 holdout - model: MMNN
# task on promoters - 44 holdout - model: BoostedMMNN
# task on promoters - 45 holdout - model: perc
# task on promoters - 45 holdout - model: FFNN
# task on promoters - 45 holdout - model: CNN
# task on promoters - 45 holdout - model: MMNN
# task on promoters - 45 holdout - model: BoostedMMNN
# task on promoters - 46 holdout - model: perc
# task on promoters - 46 holdout - model: FFNN
# task on promoters - 46 holdout - model: CNN
# task on promoters - 46 holdout - model: MMNN
# task on promoters - 46 holdout - model: BoostedMMNN
# task on promoters - 47 holdout - model: perc
# task on promoters - 47 holdout - model: FFNN
# task on promoters - 47 holdout - model: CNN
# task on promoters - 47 holdout - model: MMNN
# task on promoters - 47 holdout - model: BoostedMMNN
# task on promoters - 48 holdout - model: perc
# task on promoters - 48 holdout - model: FFNN
# task on promoters - 48 holdout - model: CNN
# task on promoters - 48 holdout - model: MMNN
# task on promoters - 48 holdout - model: BoostedMMNN
# task on promoters - 49 holdout - model: perc
# task on promoters - 49 holdout - model: FFNN
# task on promoters - 49 holdout - model: CNN
# task on promoters - 49 holdout - model: MMNN
# task on promoters - 49 holdout - model: BoostedMMNN
# task on promoters - 50 holdout - model: perc
# task on promoters - 50 holdout - model: FFNN
# task on promoters - 50 holdout - model: CNN
# task on promoters - 50 holdout - model: MMNN
# task on promoters - 50 holdout - model: BoostedMMNN
# --------------------------------------------------------------------------------
# task on enhancers - 1 holdout - model: perc
# task on enhancers - 1 holdout - model: FFNN
# task on enhancers - 1 holdout - model: CNN
# task on enhancers - 1 holdout - model: MMNN
# task on enhancers - 1 holdout - model: BoostedMMNN
# task on enhancers - 2 holdout - model: perc
# task on enhancers - 2 holdout - model: FFNN
# task on enhancers - 2 holdout - model: CNN
# task on enhancers - 2 holdout - model: MMNN
# task on enhancers - 2 holdout - model: BoostedMMNN
# task on enhancers - 3 holdout - model: perc
# task on enhancers - 3 holdout - model: FFNN
# task on enhancers - 3 holdout - model: CNN
# task on enhancers - 3 holdout - model: MMNN
# task on enhancers - 3 holdout - model: BoostedMMNN
# task on enhancers - 4 holdout - model: perc
# task on enhancers - 4 holdout - model: FFNN
# task on enhancers - 4 holdout - model: CNN
# task on enhancers - 4 holdout - model: MMNN
# task on enhancers - 4 holdout - model: BoostedMMNN
# task on enhancers - 5 holdout - model: perc
# task on enhancers - 5 holdout - model: FFNN
# task on enhancers - 5 holdout - model: CNN
# task on enhancers - 5 holdout - model: MMNN
# task on enhancers - 5 holdout - model: BoostedMMNN
# task on enhancers - 6 holdout - model: perc
# task on enhancers - 6 holdout - model: FFNN
# task on enhancers - 6 holdout - model: CNN
# task on enhancers - 6 holdout - model: MMNN
# task on enhancers - 6 holdout - model: BoostedMMNN
# task on enhancers - 7 holdout - model: perc
# task on enhancers - 7 holdout - model: FFNN
# task on enhancers - 7 holdout - model: CNN
# task on enhancers - 7 holdout - model: MMNN
# task on enhancers - 7 holdout - model: BoostedMMNN
# task on enhancers - 8 holdout - model: perc
# task on enhancers - 8 holdout - model: FFNN
# task on enhancers - 8 holdout - model: CNN
# task on enhancers - 8 holdout - model: MMNN
# task on enhancers - 8 holdout - model: BoostedMMNN
# task on enhancers - 9 holdout - model: perc
# task on enhancers - 9 holdout - model: FFNN
# task on enhancers - 9 holdout - model: CNN
# task on enhancers - 9 holdout - model: MMNN
# task on enhancers - 9 holdout - model: BoostedMMNN
# task on enhancers - 10 holdout - model: perc
# task on enhancers - 10 holdout - model: FFNN
# task on enhancers - 10 holdout - model: CNN
# task on enhancers - 10 holdout - model: MMNN
# task on enhancers - 10 holdout - model: BoostedMMNN
# task on enhancers - 11 holdout - model: perc
# task on enhancers - 11 holdout - model: FFNN
# task on enhancers - 11 holdout - model: CNN
# task on enhancers - 11 holdout - model: MMNN
# task on enhancers - 11 holdout - model: BoostedMMNN
# task on enhancers - 12 holdout - model: perc
# task on enhancers - 12 holdout - model: FFNN
# task on enhancers - 12 holdout - model: CNN
# task on enhancers - 12 holdout - model: MMNN
# task on enhancers - 12 holdout - model: BoostedMMNN
# task on enhancers - 13 holdout - model: perc
# task on enhancers - 13 holdout - model: FFNN
# task on enhancers - 13 holdout - model: CNN
# task on enhancers - 13 holdout - model: MMNN
# task on enhancers - 13 holdout - model: BoostedMMNN
# task on enhancers - 14 holdout - model: perc
# task on enhancers - 14 holdout - model: FFNN
# task on enhancers - 14 holdout - model: CNN
# task on enhancers - 14 holdout - model: MMNN
# task on enhancers - 14 holdout - model: BoostedMMNN
# task on enhancers - 15 holdout - model: perc
# task on enhancers - 15 holdout - model: FFNN
# task on enhancers - 15 holdout - model: CNN
# task on enhancers - 15 holdout - model: MMNN
# task on enhancers - 15 holdout - model: BoostedMMNN
# task on enhancers - 16 holdout - model: perc
# task on enhancers - 16 holdout - model: FFNN
# task on enhancers - 16 holdout - model: CNN
# task on enhancers - 16 holdout - model: MMNN
# task on enhancers - 16 holdout - model: BoostedMMNN
# task on enhancers - 17 holdout - model: perc
# task on enhancers - 17 holdout - model: FFNN
# task on enhancers - 17 holdout - model: CNN
# task on enhancers - 17 holdout - model: MMNN
# task on enhancers - 17 holdout - model: BoostedMMNN
# task on enhancers - 18 holdout - model: perc
# task on enhancers - 18 holdout - model: FFNN
# task on enhancers - 18 holdout - model: CNN
# task on enhancers - 18 holdout - model: MMNN
# task on enhancers - 18 holdout - model: BoostedMMNN
# task on enhancers - 19 holdout - model: perc
# task on enhancers - 19 holdout - model: FFNN
# task on enhancers - 19 holdout - model: CNN
# task on enhancers - 19 holdout - model: MMNN
# task on enhancers - 19 holdout - model: BoostedMMNN
# task on enhancers - 20 holdout - model: perc
# task on enhancers - 20 holdout - model: FFNN
# task on enhancers - 20 holdout - model: CNN
# task on enhancers - 20 holdout - model: MMNN
# task on enhancers - 20 holdout - model: BoostedMMNN
# task on enhancers - 21 holdout - model: perc
# task on enhancers - 21 holdout - model: FFNN
# task on enhancers - 21 holdout - model: CNN
# task on enhancers - 21 holdout - model: MMNN
# task on enhancers - 21 holdout - model: BoostedMMNN
# task on enhancers - 22 holdout - model: perc
# task on enhancers - 22 holdout - model: FFNN
# task on enhancers - 22 holdout - model: CNN
# task on enhancers - 22 holdout - model: MMNN
# task on enhancers - 22 holdout - model: BoostedMMNN
# task on enhancers - 23 holdout - model: perc
# task on enhancers - 23 holdout - model: FFNN
# task on enhancers - 23 holdout - model: CNN
# task on enhancers - 23 holdout - model: MMNN
# task on enhancers - 23 holdout - model: BoostedMMNN
# task on enhancers - 24 holdout - model: perc
# task on enhancers - 24 holdout - model: FFNN
# task on enhancers - 24 holdout - model: CNN
# task on enhancers - 24 holdout - model: MMNN
# task on enhancers - 24 holdout - model: BoostedMMNN
# task on enhancers - 25 holdout - model: perc
# task on enhancers - 25 holdout - model: FFNN
# task on enhancers - 25 holdout - model: CNN
# task on enhancers - 25 holdout - model: MMNN
# task on enhancers - 25 holdout - model: BoostedMMNN
# task on enhancers - 26 holdout - model: perc
# task on enhancers - 26 holdout - model: FFNN
# task on enhancers - 26 holdout - model: CNN
# task on enhancers - 26 holdout - model: MMNN
# task on enhancers - 26 holdout - model: BoostedMMNN
# task on enhancers - 27 holdout - model: perc
# task on enhancers - 27 holdout - model: FFNN
# task on enhancers - 27 holdout - model: CNN
# task on enhancers - 27 holdout - model: MMNN
# task on enhancers - 27 holdout - model: BoostedMMNN
# task on enhancers - 28 holdout - model: perc
# task on enhancers - 28 holdout - model: FFNN
# task on enhancers - 28 holdout - model: CNN
# task on enhancers - 28 holdout - model: MMNN
# task on enhancers - 28 holdout - model: BoostedMMNN
# task on enhancers - 29 holdout - model: perc
# task on enhancers - 29 holdout - model: FFNN
# task on enhancers - 29 holdout - model: CNN
# task on enhancers - 29 holdout - model: MMNN
# task on enhancers - 29 holdout - model: BoostedMMNN
# task on enhancers - 30 holdout - model: perc
# task on enhancers - 30 holdout - model: FFNN
# task on enhancers - 30 holdout - model: CNN
# task on enhancers - 30 holdout - model: MMNN
# task on enhancers - 30 holdout - model: BoostedMMNN
# task on enhancers - 31 holdout - model: perc
# task on enhancers - 31 holdout - model: FFNN
# task on enhancers - 31 holdout - model: CNN
# task on enhancers - 31 holdout - model: MMNN
# task on enhancers - 31 holdout - model: BoostedMMNN
# task on enhancers - 32 holdout - model: perc
# task on enhancers - 32 holdout - model: FFNN
# task on enhancers - 32 holdout - model: CNN
# task on enhancers - 32 holdout - model: MMNN
# task on enhancers - 32 holdout - model: BoostedMMNN
# task on enhancers - 33 holdout - model: perc
# task on enhancers - 33 holdout - model: FFNN
# task on enhancers - 33 holdout - model: CNN
# task on enhancers - 33 holdout - model: MMNN
# task on enhancers - 33 holdout - model: BoostedMMNN
# task on enhancers - 34 holdout - model: perc
# task on enhancers - 34 holdout - model: FFNN
# task on enhancers - 34 holdout - model: CNN
# task on enhancers - 34 holdout - model: MMNN
# task on enhancers - 34 holdout - model: BoostedMMNN
# task on enhancers - 35 holdout - model: perc
# task on enhancers - 35 holdout - model: FFNN
# task on enhancers - 35 holdout - model: CNN
# task on enhancers - 35 holdout - model: MMNN
# task on enhancers - 35 holdout - model: BoostedMMNN
# task on enhancers - 36 holdout - model: perc
# task on enhancers - 36 holdout - model: FFNN
# task on enhancers - 36 holdout - model: CNN
# task on enhancers - 36 holdout - model: MMNN
# task on enhancers - 36 holdout - model: BoostedMMNN
# task on enhancers - 37 holdout - model: perc
# task on enhancers - 37 holdout - model: FFNN
# task on enhancers - 37 holdout - model: CNN
# task on enhancers - 37 holdout - model: MMNN
# task on enhancers - 37 holdout - model: BoostedMMNN
# task on enhancers - 38 holdout - model: perc
# task on enhancers - 38 holdout - model: FFNN
# task on enhancers - 38 holdout - model: CNN
# task on enhancers - 38 holdout - model: MMNN
# task on enhancers - 38 holdout - model: BoostedMMNN
# task on enhancers - 39 holdout - model: perc
# task on enhancers - 39 holdout - model: FFNN
# task on enhancers - 39 holdout - model: CNN
# task on enhancers - 39 holdout - model: MMNN
# task on enhancers - 39 holdout - model: BoostedMMNN
# task on enhancers - 40 holdout - model: perc
# task on enhancers - 40 holdout - model: FFNN
# task on enhancers - 40 holdout - model: CNN
# task on enhancers - 40 holdout - model: MMNN
# task on enhancers - 40 holdout - model: BoostedMMNN
# task on enhancers - 41 holdout - model: perc
# task on enhancers - 41 holdout - model: FFNN
# task on enhancers - 41 holdout - model: CNN
# task on enhancers - 41 holdout - model: MMNN
# task on enhancers - 41 holdout - model: BoostedMMNN
# task on enhancers - 42 holdout - model: perc
# task on enhancers - 42 holdout - model: FFNN
# task on enhancers - 42 holdout - model: CNN
# task on enhancers - 42 holdout - model: MMNN
# task on enhancers - 42 holdout - model: BoostedMMNN
# task on enhancers - 43 holdout - model: perc
# task on enhancers - 43 holdout - model: FFNN
# task on enhancers - 43 holdout - model: CNN
# task on enhancers - 43 holdout - model: MMNN
# task on enhancers - 43 holdout - model: BoostedMMNN
# task on enhancers - 44 holdout - model: perc
# task on enhancers - 44 holdout - model: FFNN
# task on enhancers - 44 holdout - model: CNN
# task on enhancers - 44 holdout - model: MMNN
# task on enhancers - 44 holdout - model: BoostedMMNN
# task on enhancers - 45 holdout - model: perc
# task on enhancers - 45 holdout - model: FFNN
# task on enhancers - 45 holdout - model: CNN
# task on enhancers - 45 holdout - model: MMNN
# task on enhancers - 45 holdout - model: BoostedMMNN
# task on enhancers - 46 holdout - model: perc
# task on enhancers - 46 holdout - model: FFNN
# task on enhancers - 46 holdout - model: CNN
# task on enhancers - 46 holdout - model: MMNN
# task on enhancers - 46 holdout - model: BoostedMMNN
# task on enhancers - 47 holdout - model: perc
# task on enhancers - 47 holdout - model: FFNN
# task on enhancers - 47 holdout - model: CNN
# task on enhancers - 47 holdout - model: MMNN
# task on enhancers - 47 holdout - model: BoostedMMNN
# task on enhancers - 48 holdout - model: perc
# task on enhancers - 48 holdout - model: FFNN
# task on enhancers - 48 holdout - model: CNN
# task on enhancers - 48 holdout - model: MMNN
# task on enhancers - 48 holdout - model: BoostedMMNN
# task on enhancers - 49 holdout - model: perc
# task on enhancers - 49 holdout - model: FFNN
# task on enhancers - 49 holdout - model: CNN
# task on enhancers - 49 holdout - model: MMNN
# task on enhancers - 49 holdout - model: BoostedMMNN
# task on enhancers - 50 holdout - model: perc
# task on enhancers - 50 holdout - model: FFNN
# task on enhancers - 50 holdout - model: CNN
# task on enhancers - 50 holdout - model: MMNN
# task on enhancers - 50 holdout - model: BoostedMMNN
# --------------------------------------------------------------------------------

# %%
all_binary_classification_performance.to_csv('./performance/all_performance_perc_ffnn_cnn.csv')

# %%
from barplots import barplots

barplots(
    all_binary_classification_performance.drop(columns = ["holdout_number"]),
    groupby = ["task", "model_name", "run_type"],
    orientation = "horizontal",
    height = 5,
    subplots = True,
    minor_rotation = 10,
    show_legend = False
)
# Out:
# Rendering barplots:   0%|                                                                       | 0/27 [00:00<…
# ((<Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>,
#   <Figure size 1000x1800 with 1 Axes>),
#  (array([<AxesSubplot:title={'center':'Balanced Accuracy'}, xlabel='Balanced Accuracy'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Loss'}, xlabel='Loss'>], dtype=object),
#   array([<AxesSubplot:title={'center':'Negative likelihood ratio'}, xlabel='Negative likelihood ratio'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Threat score'}, xlabel='Threat score'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Fowlkes Mallows index'}, xlabel='Fowlkes Mallows index'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Specificity'}, xlabel='Specificity'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Diagnostic odds ratio'}, xlabel='Diagnostic odds ratio'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Prevalence threshold'}, xlabel='Prevalence threshold'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Matthews correlation coefficient'}, xlabel='Matthews correlation coefficient'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Negative predictive value'}, xlabel='Negative predictive value'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Fall out'}, xlabel='Fall out'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'AUPRC'}, xlabel='AUPRC'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Informedness'}, xlabel='Informedness'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Positive likelihood ratio'}, xlabel='Positive likelihood ratio'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Miss rate'}, xlabel='Miss rate'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'False positives over total'}, xlabel='False positives over total'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'False omission rate'}, xlabel='False omission rate'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Precision'}, xlabel='Precision'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'F1 Score'}, xlabel='F1 Score'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'True positives over total'}, xlabel='True positives over total'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Recall'}, xlabel='Recall'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Accuracy'}, xlabel='Accuracy'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'True negatives over total'}, xlabel='True negatives over total'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'AUROC'}, xlabel='AUROC'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'False negatives over total'}, xlabel='False negatives over total'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'False discovery rate'}, xlabel='False discovery rate'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Markedness'}, xlabel='Markedness'>],
#         dtype=object)))

# %% [markdown]
# ### Statistical test

# %%
from scipy.stats import wilcoxon

# %%
df = pd.read_csv('./performance/all_performance_perc_ffnn_cnn.csv', index_col = [0])
df = df.drop(columns = ['holdout_number'])
df = df[['accuracy', 'balanced_accuracy', 'AUROC', 'AUPRC', 'task', 'run_type', 'model_name']]

# %%
df
# Out:
#     accuracy  balanced_accuracy     AUROC     AUPRC       task run_type  \
# 0   0.813689           0.697693  0.810176  0.508961  promoters    train
# 1   0.817240           0.700466  0.811605  0.515446  promoters     test
# 0   0.822312           0.712302  0.865957  0.555557  promoters    train
# 1   0.824698           0.711354  0.866756  0.560782  promoters     test
# 0   0.795993           0.500000  0.746540  0.371435  promoters    train
# ..       ...                ...       ...       ...        ...      ...
# 1   0.943035           0.500000  0.594842  0.102747  enhancers     test
# 0   0.943075           0.500000  0.765941  0.227076  enhancers    train
# 1   0.943035           0.500000  0.736798  0.206375  enhancers     test
# 0   0.943727           0.532134  0.769033  0.260292  enhancers    train
# 1   0.943905           0.534344  0.759730  0.256433  enhancers     test
#
#      model_name
# 0          perc
# 1          perc
# 0          FFNN
# 1          FFNN
# 0           CNN
# ..          ...
# 1           CNN
# 0          MMNN
# 1          MMNN
# 0   BoostedMMNN
# 1   BoostedMMNN
#
# [1000 rows x 7 columns]

# %%
models = df[
    (df.model_name.isin(['MMNN', 'BoostedMMNN'])) &
    (df.run_type == 'test')
]

mmnn_scores = models[models.model_name == 'MMNN']
boostmmnn_scores = models[models.model_name == 'BoostedMMNN']

alpha = 0.01

for metric in mmnn_scores.columns[0:4]:
    
    for task in ['promoters', 'enhancers']:
        
        print(f"per il task {task}, considerando la metrica {metric}: " )
        
        mmnn_scores_task = mmnn_scores[mmnn_scores['task'] == task]
        boostmmnn_scores_task = boostmmnn_scores[boost_mmnn_scores['task'] == task]
        
        a, b = mmnn_scores_task[metric], boostmmnn_scores_task[metric]
        
        stats, p_value = wilcoxon(mmnn_scores_task[metric], boostmmnn_scores_task[metric])
        
        if(p_value > alpha):
            print(p_value, "the two models performance are statistically identical \n")
        else:
            print(p_value, "the two models performance are different")
            
            if a.mean() > b.mean():
                print("The first model is better \n")
            else:
                print("The second model is better \n")
# Out:
# per il task promoters, considerando la metrica accuracy:
# 0.024799931106832183 the two models performance are statistically identical
#
# per il task enhancers, considerando la metrica accuracy:
# 0.32027672265887963 the two models performance are statistically identical
#
# per il task promoters, considerando la metrica balanced_accuracy:
# 0.055342720444479465 the two models performance are statistically identical
#
# per il task enhancers, considerando la metrica balanced_accuracy:
# 0.061139832684513486 the two models performance are statistically identical
#
# per il task promoters, considerando la metrica AUROC:
# 0.027399815211928934 the two models performance are statistically identical
#
# per il task enhancers, considerando la metrica AUROC:
# 0.7906511428554124 the two models performance are statistically identical
#
# per il task promoters, considerando la metrica AUPRC:
# 0.5398874509526412 the two models performance are statistically identical
#
# per il task enhancers, considerando la metrica AUPRC:
# 0.3319694831715281 the two models performance are statistically identical
